# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
import sympy as sym

# %%
def f(X, n, q, b, c):
    Z = np.zeros(len(X))
    for i in range(len(X)):
        for j in range(int(n)):
            for k in range(int(n)):
                Z[i] += q[j][k]*X[i][j]*X[i][k]
                
        for j in range(int(n)):
            Z[i] += b[j]*X[i][j]    
    return Z

# %%
def f2(X, Y, n, q, b, c):
    Z = q[0][0]*X*X + q[0][1]*X*Y + q[1][0]*Y*X + q[1][1]*Y*Y + b[0]*X + b[1]*Y + int(c[0])
    return Z

# %%
def z_func(X_old, n, q, b, c):
    
    x, y, t = sym.symbols('x y t')

    X = sym.Matrix([[x, y]])
    
    T = sym.Matrix([[t]])
    
    df = sym.Matrix([[sym.diff(f2(x, y, n, q, b, c), x), 
                      sym.diff(f2(x, y, n, q, b, c), y)]])
    z = X - t * df
    z = f2(z[0], z[1], n, q, b, c)
    z_diff = sym.diff(z, t)
    eqn = sym.Eq(z_diff)
    sol = sym.solve((eqn), (t))
    sym.expr = sol[0]
    sym.expr = sym.expr.subs([(x, X_old[0][0]), (y, X_old[0][1])])
    return sym.expr

# %%
def steepest(X, Y, n, q, b, c, precision=0.0001, max_iter=200):
    X_old = np.zeros((1, 2))
    X_new = np.zeros((1, 2))
    
    X_new[0][0] = 4.9
    X_new[0][1] = 4.9

    i = 0
    Xs = np.zeros((max_iter,2))
    Ys = np.zeros(max_iter)
    
    x, y = sym.symbols('x y')
    df1 = sym.diff(f2(x, y, n, q, b, c), x)
    df2 = sym.diff(f2(x, y, n, q, b, c), y)
    
    while np.all(abs(X_new - X_old)) > precision and max_iter > i:
        Xs[i] = X_new
        Ys[i] = f2(X_new[0][0], X_new[0][1], n, q, b, c)

        X_old = X_new
        
        dfr1 = df1.evalf(subs={x: X_old[0][0], y: X_old[0][1]})
        dfr2 = df2.evalf(subs={x: X_old[0][0], y: X_old[0][1]})
        
        eps = z_func(X_old, n, q, b, c)
        
        X_new[0][0] = X_old[0][0] - eps * (dfr1)
        X_new[0][1] = X_old[0][1] - eps * (dfr2)
        
        i += 1
    return Xs, Ys

# %%
x_list, y_list = steepest(X_new, Z1, n, q, b, c)

# %%
n = input("Enter power of your function: ")
q = []
for i in range(int(n)):
    q.append(input("Enter the function's coefficient matrix q's row q[{}]: ".format(i)).split())
b = input("Enter the function's coefficient b matrix: ").split()
c = input("Enter the function's constant c: ")

for i in range(int(n)):
    q[i] = list(map(float, q[i]))
b = list(map(float, b))
c = list(map(float, c))
# Out:
# Enter power of your function: 2
# Enter the function's coefficient matrix q's row q[0]: 1 0
# Enter the function's coefficient matrix q's row q[1]: 0 3
# Enter the function's coefficient b matrix: 0 0
# Enter the function's constant c: 0

# %%
X1 = np.arange(-5, 5, 0.1)
Y1 = np.arange(-5, 5, 0.1)
Z1 = np.zeros(len(X1))

X_new = np.zeros((100,2))

for i in range(len(X1)):
    X_new[i][0] = X1[i]
    X_new[i][1] = Y1[i]
    
Z1 = f(X_new, n, q, b, c)

# %%
X1, Y1 = np.meshgrid(X1, Y1)
Z1 = X1**2 + 3*Y1**2
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X1, Y1, Z1, rstride=1, cstride=1, 
                cmap='viridis', edgecolor='none')
ax.set_title('surface')
plt.show()

# %%
plt.figure()
cs = plt.contour(X1, Y1, Z1)
plt.clabel(cs, inline=1, fontsize=10)
plt.title('Two-dimensional contour plot')
plt.show()

# %%
X, Y = zip(*x_list)
Z = y_list

ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
cs = plt.contour(X1, Y1, Z1)
plt.clabel(cs, inline=1, fontsize=10)
colors = ['b', 'g', 'm', 'c', 'orange']
for j in range(1, len(X)):
    ax[1].annotate('', xy=(X[j], Y[j]), xytext=(X[j-1], Y[j-1]),
                arrowprops={'arrowstyle': '->', 'color': 'r', 'lw': 1},
                va='center', ha='center')
ax[1].scatter(X, Y, s=40, lw=0)
ax[1].set_xlabel('X')
ax[1].set_ylabel('Y')
ax[1].set_title('Minimizing function')
# Out:
# Text(0.5, 1.0, 'Minimizing function')
